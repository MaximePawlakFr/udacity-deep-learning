# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3083, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'originated', 'term', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.367386
# Nearest to which: sie, avril, craters, allows, arroyo, hy, royals, newt,
# Nearest to world: glossaries, ldap, postulates, twentieth, tribesmen, skeptics, beginner, hymenoptera,
# Nearest to or: covenanters, nanometers, flashing, medford, supposedly, yi, fredric, saussure,
# Nearest to i: libby, softball, dismounted, censorial, ride, lambda, gemstone, trauma,
# Nearest to they: eh, fable, discordianism, benno, reduce, shipping, casper, prc,
# Nearest to with: kindly, alligators, rationalistic, shimbun, commonwealth, termite, hebron, filmfour,
# Nearest to states: kg, hypoxia, reflector, lapses, bubbled, congressman, penance, slab,
# Nearest to war: endothermy, needy, dorothea, ooze, bring, correctly, unchecked, habsburgs,
# Nearest to all: fart, blanco, amit, massacre, binding, hwi, cytoskeleton, award,
# Nearest to by: correspondent, country, fuhito, drumlins, confluence, louisiana, invertebrate, demonstrating,
# Nearest to used: vantage, sibling, benevolent, strikers, prolonged, emf, annul, endeavour,
# Nearest to its: dioxin, fearful, abwehr, cyberspace, lieu, habitats, anthropomorphism, muscovite,
# Nearest to were: salford, fiennes, burrows, stones, gothic, frazee, denunciation, tongs,
# Nearest to th: seminary, federline, vacation, archie, amassing, bubbles, banished, diagrams,
# Nearest to four: nights, aquilegia, infinitive, lyman, rigged, fortuna, ibos, filmography,
# Nearest to years: reorganised, debian, usr, generals, invited, bsi, connotations, entanglements,
# Average loss at step 2000: 4.371135
# Average loss at step 4000: 3.864711
# Average loss at step 6000: 3.792913
# Average loss at step 8000: 3.690227
# Average loss at step 10000: 3.615327
# Nearest to which: this, that, it, also, worshipper, anime, habsburgs, there,
# Nearest to world: facchetti, ldap, postulates, latinized, gustloff, participated, witnessed, trypanosomiasis,
# Nearest to or: and, than, phoned, tully, ibero, ezquerra, external, postmillennialism,
# Nearest to i: bryozoa, ride, that, catamaran, lambda, he, libby, ivory,
# Nearest to they: he, there, not, draped, it, benno, we, lindisfarne,
# Nearest to with: in, between, by, faded, at, on, document, crewe,
# Nearest to states: bottled, worldcom, kg, hydration, capt, eastenders, congenital, reflector,
# Nearest to war: needy, endothermy, self, dorothea, falsifiability, robot, propagation, marianas,
# Nearest to all: amit, keith, organic, dichotomy, schultz, insist, represented, diatomaceous,
# Nearest to by: was, with, onetime, correspondent, as, at, readers, were,
# Nearest to used: umlauts, yersinia, zane, mrna, madeline, carey, diametrically, emf,
# Nearest to its: their, the, his, xxxv, vertices, umberto, tramp, phyllis,
# Nearest to were: are, was, fence, but, phrased, been, lovelock, have,
# Nearest to th: vacation, three, four, federline, seminary, archie, startled, preterist,
# Nearest to four: six, five, three, eight, seven, nine, zero, two,
# Nearest to years: debian, dichotomy, usr, reorganised, connotations, invited, monuc, malware,
# Average loss at step 12000: 3.599733
# Average loss at step 14000: 3.574071
# Average loss at step 16000: 3.415254
# Average loss at step 18000: 3.455508
# Average loss at step 20000: 3.543038
# Nearest to which: that, this, what, it, also, who, there, but,
# Nearest to world: facchetti, postulates, latinized, trypanosomiasis, gustloff, ldap, witnessed, indifference,
# Nearest to or: than, and, hornblower, thames, karma, roper, feudalism, safed,
# Nearest to i: bryozoa, ii, libby, we, avon, witt, ventris, ride,
# Nearest to they: he, there, we, it, who, not, she, you,
# Nearest to with: between, by, in, at, involving, elkins, for, pike,
# Nearest to states: hydration, kg, length, bottled, reflector, resistors, congenital, eastenders,
# Nearest to war: needy, endothermy, self, dorothea, falsifiability, penicillium, pediatrician, marianas,
# Nearest to all: these, keith, many, organic, popularly, amit, schultz, their,
# Nearest to by: through, be, with, fro, gamelan, were, been, into,
# Nearest to used: known, umlauts, mrna, regarded, yersinia, carey, killed, benevolent,
# Nearest to its: their, his, the, her, tramp, any, xxxv, nand,
# Nearest to were: are, was, had, have, been, fence, be, is,
# Nearest to th: vacation, kendall, federline, startled, archie, algol, federative, three,
# Nearest to four: six, three, seven, eight, five, two, nine, zero,
# Nearest to years: connotations, minutes, usr, monuc, invited, debian, dichotomy, cremated,
# Average loss at step 22000: 3.502104
# Average loss at step 24000: 3.488639
# Average loss at step 26000: 3.481902
# Average loss at step 28000: 3.480842
# Average loss at step 30000: 3.507187
# Nearest to which: this, that, what, it, also, who, these, anime,
# Nearest to world: facchetti, postulates, participated, latinized, gustloff, accuses, ducal, alcindor,
# Nearest to or: and, than, engraved, stamina, shura, ibero, rye, thames,
# Nearest to i: ii, we, bryozoa, libby, neuron, you, ventris, iii,
# Nearest to they: there, we, he, it, who, not, she, you,
# Nearest to with: between, elkins, by, involving, in, for, glucose, original,
# Nearest to states: hydration, kingdom, religions, reflector, eastenders, resistors, length, kg,
# Nearest to war: needy, endothermy, dorothea, pediatrician, self, marianas, quart, eazy,
# Nearest to all: these, many, those, amit, keith, some, schultz, organic,
# Nearest to by: with, in, onetime, was, quatre, bonneville, as, were,
# Nearest to used: known, produced, written, regarded, umlauts, considered, found, mrna,
# Nearest to its: their, his, the, her, xxxv, brit, tramp, nand,
# Nearest to were: are, was, have, had, is, being, deviated, be,
# Nearest to th: vacation, kendall, eight, seven, nd, rd, two, algol,
# Nearest to four: five, six, eight, three, seven, two, nine, zero,
# Nearest to years: months, connotations, minutes, year, cremated, debian, days, chemotaxis,
# Average loss at step 32000: 3.498025
# Average loss at step 34000: 3.493588
# Average loss at step 36000: 3.452955
# Average loss at step 38000: 3.299337
# Average loss at step 40000: 3.436083
# Nearest to which: that, this, also, who, it, usually, what, there,
# Nearest to world: hbc, indifference, postulates, latinized, ducal, facchetti, smog, favored,
# Nearest to or: than, and, kristian, primordial, treasurer, chari, for, pear,
# Nearest to i: we, you, ii, he, bryozoa, t, ventris, they,
# Nearest to they: we, there, he, you, it, she, who, not,
# Nearest to with: between, by, theocratic, elkins, original, into, involving, ministerio,
# Nearest to states: kingdom, hydration, religions, resistors, capt, eastenders, countries, reflector,
# Nearest to war: needy, dated, endothermy, outrun, panoramic, interspersed, eazy, gregory,
# Nearest to all: these, both, keith, carp, every, amit, many, several,
# Nearest to by: with, fro, through, gamelan, owens, onetime, mujahedin, tranquillity,
# Nearest to used: known, considered, found, given, produced, written, applied, regarded,
# Nearest to its: their, his, her, the, any, undergraduates, xxxv, nand,
# Nearest to were: are, have, was, had, those, riverboat, these, yugoslavian,
# Nearest to th: kendall, vacation, nd, rd, st, federative, algol, devas,
# Nearest to four: six, five, three, seven, two, eight, nine, zero,
# Nearest to years: months, days, minutes, year, connotations, times, entscheidungsproblem, debian,
# Average loss at step 42000: 3.435385
# Average loss at step 44000: 3.449743
# Average loss at step 46000: 3.451749
# Average loss at step 48000: 3.356208
# Average loss at step 50000: 3.380755
# Nearest to which: this, that, also, what, often, usually, who, still,
# Nearest to world: civil, eye, ducal, remington, latinized, postulates, oeis, hbc,
# Nearest to or: and, than, but, fpss, requests, felix, kristian, ibero,
# Nearest to i: we, you, ii, he, bryozoa, she, t, catamaran,
# Nearest to they: there, we, he, you, it, she, not, these,
# Nearest to with: between, elkins, by, involving, ultimate, montoya, glucose, hinted,
# Nearest to states: kingdom, hydration, religions, nations, rl, enrollment, suisse, resistors,
# Nearest to war: needy, dated, gregory, endothermy, outrun, union, luton, eazy,
# Nearest to all: these, every, both, those, many, carp, price, each,
# Nearest to by: through, with, was, correspondent, while, guiding, as, reappear,
# Nearest to used: known, considered, given, written, applied, found, produced, available,
# Nearest to its: their, his, the, her, xxxv, our, tramp, brit,
# Nearest to were: are, was, have, had, those, be, being, commissioners,
# Nearest to th: st, nd, rd, algol, kendall, bc, ce, federative,
# Nearest to four: six, three, five, seven, eight, nine, zero, two,
# Nearest to years: days, months, times, minutes, year, entscheidungsproblem, paraphrased, cremated,
# Average loss at step 52000: 3.434982
# Average loss at step 54000: 3.429915
# Average loss at step 56000: 3.435220
# Average loss at step 58000: 3.399529
# Average loss at step 60000: 3.393791
# Nearest to which: that, what, this, it, who, however, these, gdb,
# Nearest to world: mabo, eye, civil, bowling, nation, christi, redefined, visuals,
# Nearest to or: and, than, requests, but, chari, any, for, safed,
# Nearest to i: we, you, ii, bryozoa, they, sonatas, ventris, t,
# Nearest to they: we, there, you, he, she, i, it, not,
# Nearest to with: between, elkins, by, pike, involving, ultimate, into, in,
# Nearest to states: kingdom, nations, countries, hydration, religions, rl, fans, governments,
# Nearest to war: endothermy, needy, dated, drava, interspersed, union, threes, gregory,
# Nearest to all: every, these, both, various, many, those, any, some,
# Nearest to by: through, with, reappear, gleason, tranquillity, as, grim, dusting,
# Nearest to used: known, written, considered, referred, applied, found, called, given,
# Nearest to its: their, his, her, the, our, tramp, xxxv, nand,
# Nearest to were: are, was, have, had, those, been, yugoslavian, although,
# Nearest to th: rd, five, st, bc, nd, four, ce, algol,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to years: days, months, minutes, times, year, decades, centuries, anchorage,
# Average loss at step 62000: 3.242282
# Average loss at step 64000: 3.255396
# Average loss at step 66000: 3.403728
# Average loss at step 68000: 3.394394
# Average loss at step 70000: 3.359540
# Nearest to which: that, this, what, but, also, these, still, usually,
# Nearest to world: nation, eye, mgh, bowling, proofing, visuals, charing, mabo,
# Nearest to or: and, than, while, but, chari, estimator, treasurer, protists,
# Nearest to i: we, you, ii, bryozoa, sonatas, catamaran, g, x,
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to with: between, elkins, ultimate, involving, by, pike, sarti, paideia,
# Nearest to states: kingdom, nations, countries, hydration, state, grimaldi, rl, religions,
# Nearest to war: threes, interspersed, drava, federation, treaty, gregory, endothermy, flashlight,
# Nearest to all: both, many, some, every, various, these, any, those,
# Nearest to by: through, using, with, fro, in, endo, be, needlessly,
# Nearest to used: known, written, considered, found, applied, available, produced, regarded,
# Nearest to its: their, his, the, her, any, our, tramp, your,
# Nearest to were: are, was, have, had, be, been, those, these,
# Nearest to th: bc, algol, st, rd, four, nd, ce, bce,
# Nearest to four: five, six, seven, three, eight, zero, nine, two,
# Nearest to years: days, months, minutes, decades, times, year, centuries, episodes,
# Average loss at step 72000: 3.375502
# Average loss at step 74000: 3.352372
# Average loss at step 76000: 3.319388
# Average loss at step 78000: 3.352377
# Average loss at step 80000: 3.383146
# Nearest to which: that, this, what, usually, also, these, graciously, but,
# Nearest to world: nation, eye, justifiable, proofing, mgh, coptic, forelimbs, sealed,
# Nearest to or: and, than, while, although, pons, fpss, chari, huntingdon,
# Nearest to i: we, bryozoa, ii, you, g, charted, sonatas, mtu,
# Nearest to they: we, he, there, you, she, it, these, who,
# Nearest to with: between, elkins, involving, pike, ultimate, citeaux, into, bardot,
# Nearest to states: kingdom, nations, countries, hydration, rl, state, religions, governments,
# Nearest to war: threes, treaty, drava, wars, gregory, federation, missions, endothermy,
# Nearest to all: both, every, these, various, many, several, some, any,
# Nearest to by: through, fro, using, from, mf, gamelan, including, with,
# Nearest to used: known, written, found, considered, referred, applied, available, called,
# Nearest to its: their, his, her, the, our, your, whose, sculptures,
# Nearest to were: are, had, was, have, been, although, being, those,
# Nearest to th: bc, rd, algol, nd, devas, bce, st, ce,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to years: days, months, year, minutes, times, decades, episodes, centuries,
# Average loss at step 82000: 3.412526
# Average loss at step 84000: 3.411921
# Average loss at step 86000: 3.388243
# Average loss at step 88000: 3.354116
# Average loss at step 90000: 3.366746
# Nearest to which: that, this, what, usually, also, but, these, it,
# Nearest to world: eye, nation, coptic, forelimbs, situation, manar, civil, balkan,
# Nearest to or: and, than, fpss, novak, while, but, requests, references,
# Nearest to i: we, bryozoa, ii, g, you, t, mtu, libby,
# Nearest to they: we, he, there, she, you, it, these, who,
# Nearest to with: between, elkins, involving, ultimate, in, by, crewe, citeaux,
# Nearest to states: nations, kingdom, countries, rl, state, us, airlines, hydration,
# Nearest to war: threes, treaty, wars, gregory, excited, federation, during, drava,
# Nearest to all: both, many, several, every, these, some, those, various,
# Nearest to by: through, when, without, with, using, terraced, goats, trot,
# Nearest to used: applied, known, considered, found, referred, called, written, produced,
# Nearest to its: their, his, the, her, our, your, any, sculptures,
# Nearest to were: are, was, had, have, while, although, those, these,
# Nearest to th: rd, bc, st, nd, algol, bce, eight, devas,
# Nearest to four: five, seven, three, eight, six, nine, two, zero,
# Nearest to years: days, months, minutes, decades, year, centuries, episodes, times,
# Average loss at step 92000: 3.400784
# Average loss at step 94000: 3.251234
# Average loss at step 96000: 3.359474
# Average loss at step 98000: 3.239298
# Average loss at step 100000: 3.359445
# Nearest to which: that, this, usually, what, but, these, actually, typically,
# Nearest to world: eye, coptic, mgh, catalans, proofing, nation, forelimbs, establishes,
# Nearest to or: and, than, fpss, novak, chari, upsilon, larp, natal,
# Nearest to i: we, ii, you, bryozoa, they, iii, libby, not,
# Nearest to they: we, there, he, you, she, it, i, these,
# Nearest to with: elkins, between, paideia, into, involving, including, bardot, in,
# Nearest to states: nations, kingdom, rl, countries, governments, hydration, airlines, state,
# Nearest to war: treaty, threes, gregory, waters, missions, wars, excited, declines,
# Nearest to all: these, every, both, those, many, several, various, any,
# Nearest to by: when, through, including, fro, from, reactivated, using, grim,
# Nearest to used: considered, applied, written, referred, found, known, given, available,
# Nearest to its: their, his, the, her, our, sculptures, your, rayner,
# Nearest to were: are, was, have, had, these, those, remained, been,
# Nearest to th: rd, bc, nd, algol, st, bce, repressing, fifth,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# Nearest to years: days, months, decades, minutes, year, hours, centuries, times,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# https://github.com/rndbrtrnd/udacity-deep-learning/blob/master/5_word2vec.ipynb
